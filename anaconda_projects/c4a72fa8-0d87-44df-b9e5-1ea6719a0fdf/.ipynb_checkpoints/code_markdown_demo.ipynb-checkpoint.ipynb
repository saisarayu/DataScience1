# %%
# Code vs Markdown Cells in Jupyter Notebook

# %% [markdown]
# This notebook demonstrates the difference between Code cells and Markdown cells.
#
# Code cells are used to execute Python code, while Markdown cells are used to explain the logic and provide structure to the notebook.

# %%
print("This is a Code cell example")
# Out:
# This is a Code cell example

# %% [markdown]
# The above Code cell runs a simple Python print statement and displays the output.

# %%
a = 5
b = 10
print("Sum:", a + b)
# Out:
# Sum: 15

# %% [markdown]
# The above Code cell performs addition of two variables and prints the result.

# %%
This notebook shows how Code cells are used for execution and Markdown cells are used for explanation, making the notebook more readable and structured.
