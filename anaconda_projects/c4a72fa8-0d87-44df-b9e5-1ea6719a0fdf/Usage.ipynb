# %%
# Markdown Usage in Jupyter Notebook

# %% [markdown]
# This notebook demonstrates how to use Markdown for structuring and explaining content in Jupyter Notebook.
#
# Markdown helps improve readability and makes notebooks easier to understand.

# %% [markdown]
# ## Features of Markdown
#
# Markdown allows us to:
# - Structure content using headings
# - Create lists for better readability
# - Highlight code using inline formatting

# %% [markdown]
# ### Unordered List Example
#
# - Easy to read
# - Improves clarity
# - Helps in organizing ideas

# %% [markdown]
# ### Ordered List Example
#
# 1. Start Jupyter Notebook
# 2. Create a new notebook
# 3. Add Markdown and Code cells
# 4. Execute cells

# %% [markdown]
# ### Inline Code Example
#
# The variable `x` is used to store a value in Python.

# %% [markdown]
# ### Code Block Example
#
# ```python
# x = 10
# y = 20
# print(x + y)

# %% [markdown]
# ## ✅ 8. Code Cell (simple)
#
# ```python
# x = 5
# y = 10
# print("Sum:", x + y)

# %% [markdown]
# The above code adds two numbers and prints the result.
