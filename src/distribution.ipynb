# %% [markdown]
# print("\nComparison Insights:")
#
# print("Math mean:", df["marks_math"].mean())
# print("Science mean:", df["marks_science"].mean())
# print("English mean:", df["marks_english"].mean())
#
# print("\nStandard Deviation:")
# print(df.std())

# %% [markdown]
# print(df.describe())
#
# print("\nMedians:")
# print(df.median())

# %% [markdown]
# import pandas as pd
#
# data = {
#     "marks_math": [60, 65, 70, 75, 80],
#     "marks_science": [60, 65, 70, 75, 120],  # outlier
#     "marks_english": [68, 69, 70, 71, 72]   # very stable
# }
#
# df = pd.DataFrame(data)
# print(df)
