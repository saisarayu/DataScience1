# %%
print("\nInterpretation:")
print("Value 200 is far beyond the typical range and flagged as an outlier.")
print("However, it may be a valid extreme value or a data error.")

# %%
Q1 = df["marks"].quantile(0.25)
Q3 = df["marks"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df["marks"] < lower_bound) | (df["marks"] > upper_bound)]

print("Outliers detected:")
print(outliers)

# %%
plt.boxplot(df["marks"])
plt.title("Boxplot for Marks")
plt.ylabel("Marks")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "marks": [50, 55, 60, 65, 70, 75, 200]  # 200 = obvious outlier
}

df = pd.DataFrame(data)
